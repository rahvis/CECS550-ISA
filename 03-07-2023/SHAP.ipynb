# %% [markdown]
# #SHAP Analysis
# ###Local interpretation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Source: https://www.aidancooper.co.uk/a-non-technical-guide-to-interpreting-shap-analyses/

# %% [markdown]
# ##Global interpretation

# %% [markdown]
# ![image.png](data:image/png;base64,...)
